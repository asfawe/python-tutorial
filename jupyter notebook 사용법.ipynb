# %% [markdown]
# ## Tutorial jupyter notebook
# |   |   |   |   |   |   |
# |---|---|---|---|---|---|
# |   |   |   |   |   |   |
# |   |   |   |   |   |   |
# |   |   |   |   |   |   |

# %%
# %%time

print(sum(range(1, 10000)))
# Out:
# 49995000
# Wall time: 0 ns

# %%
# %%timeit

print(sum(range(1, 10000000)))
# Out:
# 49999995000000
# 49999995000000
# 49999995000000
# 49999995000000
# 49999995000000
# 49999995000000
# 49999995000000
# 49999995000000
# 234 ms ± 2.96 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def f(x, y):
    return x + y

# %%
f(3,6)
# Out:
# 9

# %%
f?

# %%
f??

# %%
# f + shift + Tab : 툴팁형태로 도움말 생성

# %%
import random

random.randint(1, 10)
# Out:
# 3

# %% [markdown]
# ## 이미지를 업로드 합니다.
# ![%EC%8D%B8%EB%82%B4%EC%9D%BC.png](attachment:%EC%8D%B8%EB%82%B4%EC%9D%BC.png)
