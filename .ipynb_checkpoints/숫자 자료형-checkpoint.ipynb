# %%
import sys

최댓값_변수 = sys.maxsize
최댓값_변수2 = 최댓값_변수 + 1

type(최댓값_변수2), type(최댓값_변수)
# Out:
# (int, int)

# %%
최댓값_변수
# Out:
# 9223372036854775807

# %%
id(최댓값_변수)
# Out:
# 2924656491808

# %%
최댓값_변수3 = 2924656491808
id(최댓값_변수3)
# Out:
# 2924728821872

# %%
a = 1
b = 1

id(a) , id(b)
# Out:
# (140708518111024, 140708518111024)

# %%
a = 257
b = 257

id(a) , id(b)
# Out:
# (2924728822352, 2924728822256)

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a = 256
b = 256

id(a) , id(b)
# Out:
# (140708518119184, 140708518119184)

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
bin() # 2진법
oct() # 8진법
hex() # 16진법

# %%
1.2 - 1.0
# Out:
# 0.19999999999999996

# %%
11 * 0.3
11 * 0.03
11 * 0.003
# Out:
# 0.033

# %%
4.3 - 2.7
# Out:
# 1.5999999999999996

# %%
1.5 * 0.1
# Out:
# 0.15000000000000002

# %%
1.5 * 1.1
# Out:
# 1.6500000000000001

# %%
1.5 * 2.1
# Out:
# 3.1500000000000004
